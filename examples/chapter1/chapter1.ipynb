# %% [markdown]
# ## **Introduction to Integer Programming and Applications with Julia**
#
# <table>
#   <tr>
#     <td>Chapter</td>
#     <td>1 - Introduction to Integer Programming</td>
#   </tr>
#   <tr>
#     <td>Section</td>
#     <td>1.2.1 - Integer Programming</td>
#   </tr>
#   <tr>
#     <td>Author(s)</td>
#     <td>Luiz Henrique Nogueira Lorena</td>
#   </tr>
# </table>

# %%
using JuMP  # Modeling language
using HiGHS # Solver

# Create the model
model = JuMP.Model(HiGHS.Optimizer)

# Silent mode (solver output is not printed)
JuMP.set_silent(model)

# Decision variables
@variable(model, x1, Bin)
@variable(model, x2, Bin)

# Objective
@objective(model, Min, 7x1 + 10x2)

# Constraint
@constraint(model, 3x1 + 5x2 >= 7)

# Optimize
JuMP.optimize!(model)

# Print model
print("Model:\n$model")

# Extract solution
println("Solution:")
println("x1 = ", JuMP.value(x1))
println("x2 = ", JuMP.value(x2))
println("Objective value = ", JuMP.objective_value(model))
# Out:
# Model:
# Min 7 x1 + 10 x2
# Subject to
#  3 x1 + 5 x2 ≥ 7
#  x1 binary
#  x2 binary
# Solution:
# x1 = 1.0
# x2 = 1.0
# Objective value = 17.0

# %% [markdown]
# <table>
#   <tr>
#     <td>Chapter</td>
#     <td>1 - Introduction to Integer Programming</td>
#   </tr>
#   <tr>
#     <td>Section</td>
#     <td>1.2.2 - Linear Programming</td>
#   </tr>
#   <tr>
#     <td>Author(s)</td>
#     <td>Luiz Henrique Nogueira Lorena</td>
#   </tr>
# </table>

# %%
using JuMP  # Modeling language
using HiGHS # Solver

# Create the model
model = JuMP.Model(HiGHS.Optimizer)

# Silent mode (solver output is not printed)
JuMP.set_silent(model)

# Decision variables
@variable(model, 0 <= x1 <= 1)
@variable(model, 0 <= x2 <= 1)

# Objective
@objective(model, Min, 7x1 + 10x2)

# Constraint
@constraint(model, 3x1 + 5x2 >= 7)

# Optimize
JuMP.optimize!(model)

# Print model
print("Model:\n$model")

# Extract solution
println("Solution:")
println("x1 = ", JuMP.value(x1))
println("x2 = ", JuMP.value(x2))
println("Objective value = ", JuMP.objective_value(model))
# Out:
# Model:
# Min 7 x1 + 10 x2
# Subject to
#  3 x1 + 5 x2 ≥ 7
#  x1 ≥ 0
#  x2 ≥ 0
#  x1 ≤ 1
#  x2 ≤ 1
# Solution:
# x1 = 0.6666666666666666
# x2 = 1.0
# Objective value = 14.666666666666666
