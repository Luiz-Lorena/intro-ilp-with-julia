# %%
# -------------------------------------------------------------
#  Code for: "Introduction to Integer Programming and Applications with Julia"
#  Chapter: 2 – Knapsack problems
#  Section: Exercise 2 - Binary Knapsack Problem (BKP)
#  Author(s): Luiz Henrique Nogueira Lorena
# -------------------------------------------------------------

using JuMP  # Modeling language
using HiGHS # Solver

# Data
W = 14              # capacity
w = [5, 7, 4, 3]    # weights
v = [16, 22, 12, 8] # values
n = length(v);      # number of items

# Model
model = JuMP.Model(HiGHS.Optimizer)

# Silent mode (solver output is not printed)
JuMP.set_silent(model)

# Decision variables
@variable(model, x[1:n], Bin)

# Objective
@objective(model, Max, sum(v[i]*x[i] for i = 1:n))

# Constraint
@constraint(model, sum(w[i]*x[i] for i = 1:n) <= W)

# Print model
print("Model:\n$model")

# Solve model
JuMP.optimize!(model)

# Display solution  
println("\nSolution:")
for i in 1:n
    println("x[$i] = ", JuMP.value(x[i]))
end
println("\nObjective = ", JuMP.objective_value(model))
# Out:
# Model:
# Max 16 x[1] + 22 x[2] + 12 x[3] + 8 x[4]
# Subject to
#  5 x[1] + 7 x[2] + 4 x[3] + 3 x[4] <= 14
#  x[1] binary
#  x[2] binary
#  x[3] binary
#  x[4] binary
#
# Solution:
# x[1] = 0.0
# x[2] = 1.0
# x[3] = 1.0
# x[4] = 1.0
#
# Objective = 42.0

# %%
# -------------------------------------------------------------
#  Code for: "Introduction to Integer Programming and Applications with Julia"
#  Chapter: 2 – Knapsack problems
#  Section: Exercise 2 - Integer Knapsack Problem (IKP)
#  Author(s): Luiz Henrique Nogueira Lorena
# -------------------------------------------------------------

using JuMP  # Modeling language
using HiGHS # Solver

# Data
W = 14              # capacity
w = [5, 7, 4, 3]    # weights
v = [16, 22, 12, 8] # values
n = length(v);      # number of items

# Model
model = JuMP.Model(HiGHS.Optimizer)

# Silent mode (solver output is not printed)
JuMP.set_silent(model)

# Decision variables
@variable(model, x[1:n] >= 0, Int)

# Objective
@objective(model, Max, sum(v[i]*x[i] for i = 1:n))

# Constraint
@constraint(model, sum(w[i]*x[i] for i = 1:n) <= W)

# Print model
print("Model:\n$model")

# Solve model
JuMP.optimize!(model)

# Display solution  
println("\nSolution:")
for i in 1:n
    println("x[$i] = ", JuMP.value(x[i]))
end
println("\nObjective = ", JuMP.objective_value(model))
# Out:
# Model:
# Max 16 x[1] + 22 x[2] + 12 x[3] + 8 x[4]
# Subject to
#  5 x[1] + 7 x[2] + 4 x[3] + 3 x[4] <= 14
#  x[1] >= 0
#  x[2] >= 0
#  x[3] >= 0
#  x[4] >= 0
#  x[1] integer
#  x[2] integer
#  x[3] integer
#  x[4] integer
#
# Solution:
# x[1] = -0.0
# x[2] = 2.0
# x[3] = -0.0
# x[4] = -0.0
#
# Objective = 44.0
